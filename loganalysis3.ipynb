# %%
# imports 
import spacy
import en_core_web_sm
from spacy import displacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
nlp = en_core_web_sm.load()

logFile = open('./apache3.log', 'r')
logs = logFile.read()
logFile.close()

doc = nlp(logs[:3000])

token_list = [token.text for token in doc]
print(token_list)
# Out:
# ['[', 'Sun', 'Dec', '04', '04:47:44', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:47:44', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:51:08', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6725', 'in', 'scoreboard', 'slot', '10', '\n', '[', 'Sun', 'Dec', '04', '04:51:09', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6726', 'in', 'scoreboard', 'slot', '8', '\n', '[', 'Sun', 'Dec', '04', '04:51:09', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6728', 'in', 'scoreboard', 'slot', '6', '\n', '[', 'Sun', 'Dec', '04', '04:51:14', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:51:14', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:51:14', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:51:18', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:51:18', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:51:18', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:51:37', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6736', 'in', 'scoreboard', 'slot', '10', '\n', '[', 'Sun', 'Dec', '04', '04:51:38', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6733', 'in', 'scoreboard', 'slot', '7', '\n', '[', 'Sun', 'Dec', '04', '04:51:38', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6734', 'in', 'scoreboard', 'slot', '9', '\n', '[', 'Sun', 'Dec', '04', '04:51:52', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:51:52', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:51:55', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:52:04', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6738', 'in', 'scoreboard', 'slot', '6', '\n', '[', 'Sun', 'Dec', '04', '04:52:04', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6741', 'in', 'scoreboard', 'slot', '9', '\n', '[', 'Sun', 'Dec', '04', '04:52:05', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6740', 'in', 'scoreboard', 'slot', '7', '\n', '[', 'Sun', 'Dec', '04', '04:52:05', '2005', ']', '[', 'notice', ']', 'jk2_init', '(', ')', 'Found', 'child', '6737', 'in', 'scoreboard', 'slot', '8', '\n', '[', 'Sun', 'Dec', '04', '04:52:12', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:52:12', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:52:12', '2005', ']', '[', 'notice', ']', 'workerEnv.init', '(', ')', 'ok', '/etc', '/', 'httpd', '/', 'conf', '/', 'workers2.properties', '\n', '[', 'Sun', 'Dec', '04', '04:52:15', '2005', ']', '[', 'error', ']', 'mod_jk', 'child', 'workerEnv', 'in', 'error', 'state', '6', '\n', '[', 'Sun', 'Dec', '04', '04:52:15', '2005', ']', '[', ...

# %%
stop_words = nlp.Defaults.stop_words
 
stop_words |= {'-', '/', '"', '[', ']', '(', ')'} # custom stop words appended

filtered_list = []
for token in token_list:
    if token not  in stop_words:
        filtered_list.append(token)
print(filtered_list)
# Out:
# ['Sun', 'Dec', '04', '04:47:44', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:47:44', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:51:08', '2005', 'notice', 'jk2_init', 'Found', 'child', '6725', 'scoreboard', 'slot', '10', '\n', 'Sun', 'Dec', '04', '04:51:09', '2005', 'notice', 'jk2_init', 'Found', 'child', '6726', 'scoreboard', 'slot', '8', '\n', 'Sun', 'Dec', '04', '04:51:09', '2005', 'notice', 'jk2_init', 'Found', 'child', '6728', 'scoreboard', 'slot', '6', '\n', 'Sun', 'Dec', '04', '04:51:14', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:51:14', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:51:14', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:51:18', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:51:18', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:51:18', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:51:37', '2005', 'notice', 'jk2_init', 'Found', 'child', '6736', 'scoreboard', 'slot', '10', '\n', 'Sun', 'Dec', '04', '04:51:38', '2005', 'notice', 'jk2_init', 'Found', 'child', '6733', 'scoreboard', 'slot', '7', '\n', 'Sun', 'Dec', '04', '04:51:38', '2005', 'notice', 'jk2_init', 'Found', 'child', '6734', 'scoreboard', 'slot', '9', '\n', 'Sun', 'Dec', '04', '04:51:52', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:51:52', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:51:55', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:52:04', '2005', 'notice', 'jk2_init', 'Found', 'child', '6738', 'scoreboard', 'slot', '6', '\n', 'Sun', 'Dec', '04', '04:52:04', '2005', 'notice', 'jk2_init', 'Found', 'child', '6741', 'scoreboard', 'slot', '9', '\n', 'Sun', 'Dec', '04', '04:52:05', '2005', 'notice', 'jk2_init', 'Found', 'child', '6740', 'scoreboard', 'slot', '7', '\n', 'Sun', 'Dec', '04', '04:52:05', '2005', 'notice', 'jk2_init', 'Found', 'child', '6737', 'scoreboard', 'slot', '8', '\n', 'Sun', 'Dec', '04', '04:52:12', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:52:12', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:52:12', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:52:15', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '6', '\n', 'Sun', 'Dec', '04', '04:52:15', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '7', '\n', 'Sun', 'Dec', '04', '04:52:15', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '7', '\n', 'Sun', 'Dec', '04', '04:52:36', '2005', 'notice', 'jk2_init', 'Found', 'child', '6748', 'scoreboard', 'slot', '6', '\n', 'Sun', 'Dec', '04', '04:52:36', '2005', 'notice', 'jk2_init', 'Found', 'child', '6744', 'scoreboard', 'slot', '10', '\n', 'Sun', 'Dec', '04', '04:52:36', '2005', 'notice', 'jk2_init', 'Found', 'child', '6745', 'scoreboard', 'slot', '8', '\n', 'Sun', 'Dec', '04', '04:52:49', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:52:49', '2005', 'notice', 'workerEnv.init', 'ok', '/etc', 'httpd', 'conf', 'workers2.properties', '\n', 'Sun', 'Dec', '04', '04:52:52', '2005', 'error', 'mod_jk', 'child', 'workerEnv', 'error', 'state', '7', '\n', 'Sun', 'Dec', '04', '04:5 ...

# %%
displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:47:44
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  2005] [notice] workerEnv.init() ok /etc/httpd/conf/workers2.properties</br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:47:44
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  2005] [error] mod_jk child
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     workerEnv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in error state
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:51:08
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  2005] [notice] jk2_init() Found child
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6725
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in scoreboard slot
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:51:09
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ] [notice] jk2_init() Found child
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6726
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in scoreboard slot
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:51:09
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ] [notice] jk2_init() Found child
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6728
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in scoreboard slot
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04:51:14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  2005] [notice] workerEnv.init() ok /etc/httpd/conf/workers2.properties</br>[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Dec 04
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase

# %%
from spacy.matcher import Matcher
from spacy.attrs import *
matcher = Matcher(nlp.vocab)

patterns = {
    'is_error':[{'lower':'error'}],
    
}

for label,pattern in patterns.iteritems():
    matcher.add(label, None, pattern)

matches = matcher(doc)

for match in matches:
    print(doc[match[1]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8cc49e391ba3> in <module>
#       7 }
#       8
# ----> 9 for label,pattern in patterns.iteritems():
#      10     matcher.add(label, None, pattern)
#      11
#
# AttributeError: 'dict' object has no attribute 'iteritems'
